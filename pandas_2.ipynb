# %%
import pandas as pd

# %%
#creating data frame
df=pd.read_csv('/Users/apekshagyawali/Downloads/seattle-weather.csv')
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
#printing date column
df.date
# Out:
# 0       2012-01-01
# 1       2012-01-02
# 2       2012-01-03
# 3       2012-01-04
# 4       2012-01-05
#            ...
# 1456    2015-12-27
# 1457    2015-12-28
# 1458    2015-12-29
# 1459    2015-12-30
# 1460    2015-12-31
# Name: date, Length: 1461, dtype: object

# %%
type(df.date)
# Out:
# pandas.core.series.Series

# %%
df.temp_max.mean()
# Out:
# 16.43908281998628

# %%
df['temp_max'].max()
# Out:
# 35.6

# %%
#printing temp>=25
df[df.temp_max>=25]
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 133   2012-05-13            0.0      25.6       9.4   4.2     sun
# 134   2012-05-14            0.0      26.7      12.8   3.8     sun
# 187   2012-07-06            0.0      25.0      11.1   2.1     sun
# 188   2012-07-07            0.0      26.7      12.8   3.8     sun
# 189   2012-07-08            0.0      28.3      14.4   2.8    rain
# ...          ...            ...       ...       ...   ...     ...
# 1333  2015-08-26            0.0      28.3      13.9   1.7     sun
# 1334  2015-08-27            0.0      29.4      14.4   2.1     sun
# 1348  2015-09-10            0.0      25.0      14.4   3.6     fog
# 1349  2015-09-11            0.0      27.2      15.0   3.1     sun
# 1350  2015-09-12            0.0      26.7      14.4   2.1     sun
#
# [241 rows x 6 columns]

# %%
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1461, step=1)

# %%
#set_index() method
df.set_index('date', inplace=True)

# %%
df
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain
# ...                   ...       ...       ...   ...      ...
# 2015-12-27            8.6       4.4       1.7   2.9     rain
# 2015-12-28            1.5       5.0       1.7   1.3     rain
# 2015-12-29            0.0       7.2       0.6   2.6      fog
# 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
df.loc['2012-01-01']
# Out:
# precipitation        0.0
# temp_max            12.8
# temp_min             5.0
# wind                 4.7
# weather          drizzle
# Name: 2012-01-01, dtype: object

# %%
#reset index
df.reset_index(inplace=True)
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
#creating datafram using python dictionary
weather_data={
    'date' : ['2012-01-01','2012-01-02','2012-01-03'],
    'precipitation' :[0.0,10.9,0.8],
    'wind' :[4.7,4.5,2.3]
}
df=pd.DataFrame(weather_data)
df
# Out:
#          date  precipitation  wind
# 0  2012-01-01            0.0   4.7
# 1  2012-01-02           10.9   4.5
# 2  2012-01-03            0.8   2.3

# %%
#skip rows in dataframe using "skiprows"

df=pd.read_csv('/Users/apekshagyawali/Downloads/seattle-weather.csv',skiprows=1)
df
# Out:
#       2012-01-01   0.0  12.8  5.0  4.7 drizzle
# 0     2012-01-02  10.9  10.6  2.8  4.5    rain
# 1     2012-01-03   0.8  11.7  7.2  2.3    rain
# 2     2012-01-04  20.3  12.2  5.6  4.7    rain
# 3     2012-01-05   1.3   8.9  2.8  6.1    rain
# 4     2012-01-06   2.5   4.4  2.2  2.2    rain
# ...          ...   ...   ...  ...  ...     ...
# 1455  2015-12-27   8.6   4.4  1.7  2.9    rain
# 1456  2015-12-28   1.5   5.0  1.7  1.3    rain
# 1457  2015-12-29   0.0   7.2  0.6  2.6     fog
# 1458  2015-12-30   0.0   5.6 -1.0  3.4     sun
# 1459  2015-12-31   0.0   5.6 -2.1  3.5     sun
#
# [1460 rows x 6 columns]

# %%
#import data from CSV files with "null header"
df=pd.read_csv('/Users/apekshagyawali/Downloads/seattle-weather.csv',header=None,names=["date","precipitation","temp_max","temp_min","wind","weather"])
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0           date  precipitation  temp_max  temp_min  wind  weather
# 1     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2     2012-01-02           10.9      10.6       2.8   4.5     rain
# 3     2012-01-03            0.8      11.7       7.2   2.3     rain
# 4     2012-01-04           20.3      12.2       5.6   4.7     rain
# ...          ...            ...       ...       ...   ...      ...
# 1457  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1458  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1459  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1460  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1461  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1462 rows x 6 columns]

# %%
df=pd.read_csv('/Users/apekshagyawali/Downloads/seattle-weather.csv')
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
#read limited data from CSV file
df=pd.read_csv('/Users/apekshagyawali/Downloads/seattle-weather.csv', nrows=3)
df
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain

# %%
#use group by based on weather
g=df.groupby('weather')

# %%
for weather, weather_df in g:
    print(weather)
    print(weather_df)
# Out:
# drizzle
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# rain
#          date  precipitation  temp_max  temp_min  wind weather
# 1  2012-01-02           10.9      10.6       2.8   4.5    rain
# 2  2012-01-03            0.8      11.7       7.2   2.3    rain

# %%
#access specific dataframe
g.get_group('sun')
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 7     2012-01-08            0.0      10.0       2.8   2.0     sun
# 10    2012-01-11            0.0       6.1      -1.1   5.1     sun
# 11    2012-01-12            0.0       6.1      -1.7   1.9     sun
# 12    2012-01-13            0.0       5.0      -2.8   1.3     sun
# 32    2012-02-02            0.0       8.3       1.7   2.6     sun
# ...          ...            ...       ...       ...   ...     ...
# 1427  2015-11-28            0.0       7.2      -2.7   1.0     sun
# 1443  2015-12-14            0.0       7.8       1.7   1.7     sun
# 1455  2015-12-26            0.0       4.4       0.0   2.5     sun
# 1459  2015-12-30            0.0       5.6      -1.0   3.4     sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5     sun
#
# [640 rows x 6 columns]

# %%
g.max()
# Out:
#                date  precipitation  temp_max  temp_min  wind
# weather
# drizzle  2012-01-01            0.0      12.8       5.0   4.7
# rain     2012-01-03           10.9      11.7       7.2   4.5

# %%
g.mean()
# Out:
#          precipitation  temp_max  temp_min  wind
# weather
# drizzle           0.00     12.80       5.0   4.7
# rain              5.85     11.15       5.0   3.4

# %%
g.describe()
# Out:
#         precipitation                                                temp_max  \
#                 count  mean       std  min    25%   50%    75%   max    count
# weather
# drizzle           1.0  0.00       NaN  0.0  0.000  0.00  0.000   0.0      1.0
# rain              2.0  5.85  7.141778  0.8  3.325  5.85  8.375  10.9      2.0
#
#                 ... temp_min       wind                                       \
#           mean  ...      75%  max count mean       std  min   25%  50%   75%
# weather         ...
# drizzle  12.80  ...      5.0  5.0   1.0  4.7       NaN  4.7  4.70  4.7  4.70
# rain     11.15  ...      6.1  7.2   2.0  3.4  1.555635  2.3  2.85  3.4  3.95
#
#
#          max
# weather
# drizzle  4.7
# rain     4.5
#
# [2 rows x 32 columns]

# %%
#plotting corresponds to precipitation, temp_max, temp_min and wind
# %matplotlib inline
g.plot()
# Out:
# weather
# drizzle    AxesSubplot(0.125,0.11;0.775x0.77)
# rain       AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object
